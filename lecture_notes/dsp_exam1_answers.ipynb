# %% [markdown]
# ## Prelim Problem Set Answers

# %% [markdown]
# ## Part 1.
# Solve for the magnitude and angle of the linear transformations given. Provide necessary solutions numerically (hand-solved) and computationally (using a Python program). Also provide the necessary solutions vector plots of the given matrices and their transformations (nos. 1-5.)

# %% [markdown]
# $$H = \frac{1}{\sqrt{2}} \begin{pmatrix} 1 & 1 \\ 1 & -1 \end{pmatrix}, Y = \begin{pmatrix} 0 & -i \\ i & 0 \end{pmatrix}, O = \begin{pmatrix} 1 & 0 \\ 1 & 1 \end{pmatrix}$$

# %%
import numpy as np

# %%
H = (1/np.sqrt(2))*np.array([[1,1],[1,-1]])
Y  = (1j)*np.array([[0,-1],[1,0]])
O = np.array([[1,0],[1,1]])

print(f'H: \n {H}')
print(f'Y: \n {Y}')
print(f'O: \n {O}')
# Out:
# H:
#  [[ 0.70710678  0.70710678]
#  [ 0.70710678 -0.70710678]]
# Y:
#  [[ 0.+0.j -0.-1.j]
#  [ 0.+1.j  0.+0.j]]
# O:
#  [[1 0]
#  [1 1]]

# %% [markdown]
# ### $H \cdot Y$
# $H \cdot Y = \frac{1}{\sqrt{2}} \begin{pmatrix} 1 & 1 \\ 1 & -1 \end{pmatrix} \cdot \begin{pmatrix} 0 & -i \\ i & 0 \end{pmatrix}$
#
# $H \cdot Y = \frac{i}{\sqrt{2}} \begin{pmatrix} 1 & 1 \\ 1 & -1 \end{pmatrix} \cdot \begin{pmatrix} 0 & -1 \\ 1 & 0 \end{pmatrix}$
#
# $H \cdot Y = \frac{i}{\sqrt{2}} \begin{pmatrix} 1 & -1 \\ -1 & -1 \end{pmatrix} $

# %%
manual_1_1 = (1j/np.sqrt(2))*np.array([[1,-1],[-1,-1]])

# %%
## Validation
np.allclose(manual_1_1, H@Y)
# Out:
# True

# %% [markdown]
# ### $Y \cdot H$
# $Y \cdot H = \begin{pmatrix} 0 & -i \\ i & 0 \end{pmatrix} \cdot \frac{1}{\sqrt{2}} \begin{pmatrix} 1 & 1 \\ 1 & -1 \end{pmatrix}$
#
# $Y \cdot H = \frac{i}{\sqrt{2}} \begin{pmatrix} 0 & -1 \\ 1 & 0 \end{pmatrix} \cdot \begin{pmatrix} 1 & 1 \\ 1 & -1 \end{pmatrix}$
#
# $Y \cdot H = \frac{i}{\sqrt{2}} \begin{pmatrix} -1 & 1 \\ 1 & 1 \end{pmatrix} $

# %%
manual_1_2 = (1j/np.sqrt(2))*np.array([[-1,1],[1,1]])

# %%
## Validation
np.allclose(manual_1_2, Y@H)
# Out:
# True

# %% [markdown]
# ### $H \cdot H$
# $H \cdot H = \frac{1}{\sqrt{2}} \begin{pmatrix} 1 & 1 \\ 1 & -1 \end{pmatrix} \cdot \frac{1}{\sqrt{2}} \begin{pmatrix} 1 & 1 \\ 1 & -1 \end{pmatrix}$
#
# $H \cdot H = (\frac{1}{\sqrt{2}}\cdot \frac{1}{\sqrt{2}}) \begin{pmatrix} 1 & 1 \\ 1 & -1 \end{pmatrix} \cdot \begin{pmatrix} 1 & 1 \\ 1 & -1 \end{pmatrix}$
#
# $H \cdot H = \frac{1}{2} \begin{pmatrix} 2 & 0 \\ 0 & 2 \end{pmatrix} = \begin{pmatrix} 1 & 0 \\ 0 & 1 \end{pmatrix} = I$

# %%
manual_1_3 = np.eye(2)

# %%
## Validation
np.allclose(manual_1_3, H@H)
# Out:
# True

# %% [markdown]
# ### $Y \cdot H \cdot O$
# $Y \cdot H \cdot O = Y \cdot (H \cdot O) =  \begin{pmatrix} 0 & -i \\ i & 0 \end{pmatrix} \cdot \left[\frac{1}{\sqrt{2}} \begin{pmatrix} 1 & 1 \\ 1 & -1 \end{pmatrix}  \cdot \begin{pmatrix} 1 & 0 \\ 1 & 1 \end{pmatrix} \right]$
#
# $Y \cdot H \cdot O = \frac{i}{\sqrt{2}} \begin{pmatrix} 0 & -1 \\ 1 & 0 \end{pmatrix} \cdot \begin{pmatrix} 2 & 1 \\ 0 & -1 \end{pmatrix}$
#
# $Y \cdot H \cdot O = \frac{i}{\sqrt{2}} \begin{pmatrix} 0 & 1 \\ 2 & 1 \end{pmatrix} $

# %%
manual_1_4 = (1j/np.sqrt(2))*np.array([[0,1],[2,1]])

# %%
## Validation
np.allclose(manual_1_4, Y@H@O)
# Out:
# True

# %% [markdown]
# ### $H \cdot Y \cdot H \cdot O$
# $H \cdot Y \cdot H \cdot O = H \cdot [ Y \cdot (H \cdot O)] = \frac{1}{\sqrt{2}} \begin{pmatrix} 1 & 1 \\ 1 & -1 \end{pmatrix} \cdot \left[ \begin{pmatrix} 0 & -i \\ i & 0 \end{pmatrix} \cdot \left[ \frac{1}{\sqrt{2}} \begin{pmatrix} 1 & 1 \\ 1 & -1 \end{pmatrix}  \cdot \begin{pmatrix} 1 & 0 \\ 1 & 1 \end{pmatrix} \right] \right]$
#
# Where $Y \cdot H \cdot O$ is from 1.4
#
# $H \cdot Y \cdot H \cdot O$ = $\frac{1}{\sqrt{2}} \begin{pmatrix} 1 & 1 \\ 1 & -1 \end{pmatrix} \cdot \left[ \frac{i}{\sqrt{2}} \begin{pmatrix} 0 & 1 \\ 2 & 1 \end{pmatrix} \right] $
#
# $H \cdot Y \cdot H \cdot O = \frac{i}{2} \begin{pmatrix} 2 & 2 \\ -2 & 0 \end{pmatrix} = \begin{pmatrix} i & i \\ -i & 0 \end{pmatrix}$

# %%
manual_1_5 = (1j)*np.array([[1,1],[-1,0]])

# %%
## Validation
np.allclose(manual_1_5, H@Y@H@O)
# Out:
# True

# %% [markdown]
# ## Part 2.
# Solve for the determinants of 𝐻 and 𝑌. Provide necessary solutions numerically (hand-solved) and computationally

# %% [markdown]
# $|H| = \left(\frac{1}{\sqrt{2}} \cdot \frac{-1}{\sqrt{2}} \right) - \left( \frac{1}{\sqrt{2}} \cdot \frac{1}{\sqrt{2}} \right)$
#
# $|H| = \left(\frac{-1}{2} \right) - \left( \frac{1}{2} \right)$
#
# $|H| = \frac{-2}{2} = -1$

# %%
np.allclose(-1, np.linalg.det(H))
# Out:
# True

# %% [markdown]
# $|Y| = \left(0 \cdot 0 \right) - \left( i \cdot -i \right)$
#
# $|Y| =  - \left( i^4 \right) = -1$

# %%
np.allclose(-1, np.linalg.det(Y))
# Out:
# True

# %% [markdown]
# ## Part 3.
#
# Determine whether the resulting linear transformations are linearly dependent. Provide necessary solutions

# %% [markdown]
# Let
# $$
# A = \begin{pmatrix}
# 5 & 0 & 0 \\
# 0 & 5 & 0 \\
# 0 & 0 & 5
# \end{pmatrix}
# $$
# $$
# B = \begin{pmatrix}
# 1 & 0 & 5 \\
# 2 & 7 & 6 \\
# 6 & 4 & 7
# \end{pmatrix}
# $$
# $$X = A \cdot B$$

# %% [markdown]
# $
# X = 5 \begin{pmatrix}
# 1 & 0 & 0 \\
# 0 & 1 & 0 \\
# 0 & 0 & 1
# \end{pmatrix}
# \cdot \begin{pmatrix}
# 1 & 0 & 5 \\
# 2 & 7 & 6 \\
# 6 & 4 & 7
# \end{pmatrix} = 5I \cdot \begin{pmatrix}
# 1 & 0 & 5 \\
# 2 & 7 & 6 \\
# 6 & 4 & 7
# \end{pmatrix} = 5\begin{pmatrix}
# 1 & 0 & 5 \\
# 2 & 7 & 6 \\
# 6 & 4 & 7
# \end{pmatrix} = \begin{pmatrix}
# 5 & 0 & 25 \\
# 10 & 35 & 30 \\
# 30 & 20 & 35
# \end{pmatrix}
# $
#
# $|X| = 5\left| \begin{pmatrix}
# 35 & 30 \\
# 20 & 35
# \end{pmatrix}\right| - 0\left| \begin{pmatrix}
# 10 & 30 \\
# 30 & 35
# \end{pmatrix}\right| + 25\left| \begin{pmatrix}
# 10 & 35 \\
# 30 & 20
# \end{pmatrix}\right| = 5\left| \begin{pmatrix}
# 35 & 30 \\
# 20 & 35
# \end{pmatrix}\right| + 25\left| \begin{pmatrix}
# 10 & 35 \\
# 30 & 20
# \end{pmatrix}\right|$
#
# $|X| = 5 \left[ (35 \cdot 35) - (30 \cdot 20) \right] + 25 \left[ (10 \cdot 20) - (30 \cdot 35) \right]$
#
# $|X| = 5 \left[ 1225 - 600 \right] + 25 \left[200 - 1050 \right]$
#
# $|X| = 5\cdot 625 + 25 \left(-850 \right)$
#
# $|X| = 3125 - 21250 = -18125$
#
# $\therefore X \text{ is linearly independent}$

# %%
A = 5*np.eye(3)
B = np.array([
    [1,0,5],
    [2,7,6],
    [6,4,7]
])

np.allclose(-18125, np.linalg.det(A@B))
# Out:
# True

# %%
np.linalg.det(A@B)
# Out:
# -18124.99999999999

# %% [markdown]
# Let
# $$
# C = \begin{pmatrix}
# 1 & 2 & 6 \\
# 3 & 15 & 4 \\
# 2 & 10 & 3
# \end{pmatrix}
# $$
# $$
# D = \begin{pmatrix}
# 5 & 2 & 4 \\
# 6 & 2 & 4 \\
# 0 & 1 & 1
# \end{pmatrix}
# $$
# $$M = C \cdot D$$

# %% [markdown]
# $
# M = \begin{pmatrix}
# 1 & 2 & 6 \\
# 3 & 15 & 4 \\
# 2 & 10 & 3
# \end{pmatrix}
# \cdot \begin{pmatrix}
# 5 & 2 & 4 \\
# 6 & 2 & 4 \\
# 0 & 1 & 1
# \end{pmatrix} = \begin{pmatrix}
# 17 &  12 &  18 \\
# 105&  40 &  76 \\
# 70&  27&  51
# \end{pmatrix}
# $
#
# $|M| = 17\left| \begin{pmatrix}
# 40 & 76 \\
# 27 & 51
# \end{pmatrix}\right| + 12\left| \begin{pmatrix}
# 105 & 76 \\
# 70 & 51
# \end{pmatrix}\right| - 18\left| \begin{pmatrix}
# 105 & 40 \\
# 76 & 27
# \end{pmatrix}\right|
# $
#
# $|M| = 17 \left[ (40 \cdot 51) - (76 \cdot 27) \right] + 12 \left[ (105 \cdot 51) - (76 \cdot 70) \right] - 18 \left[ (105 \cdot 27) - (70 \cdot 40) \right]$
#
# $|M| = 17 \left[ 2040 - 2052 \right] + 12 \left[ 5355 - 5320 \right] - 18 \left[2835 - 2800 \right]$
#
# $|M| = 17(-12) + 12(35) - 18(35)$
#
# $|M| = -204 - 420 + 630 = 6$
#
# $\therefore M \text{ is linearly independent}$

# %%
C = np.array([
    [1,2,6],
    [3,15,4],
    [2,10,3]
])
D = np.array([
    [5,2,4],
    [6,2,4],
    [0,1,1]
])
M = C@D
M
# Out:
# array([[ 17,  12,  18],
#        [105,  40,  76],
#        [ 70,  27,  51]])

# %%
np.allclose(6, np.linalg.det(M))
# Out:
# True

# %% [markdown]
# ## Part 4.
#
# Plot the signal corresponding to the following vectors whereas $T$ is the time vector and $G$ is the vector corresponding to the amplitudes of the signal.
#
# $$T = \begin{pmatrix} 0 & \frac{\pi}{4} & \frac{\pi}{2} & \frac{3\pi}{4} & \pi\end{pmatrix}$$
# $$G = \begin{pmatrix} 5 & 3 & 0 & -3 & 5\end{pmatrix}$$

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter, MultipleLocator

# %%
T = np.array([0, np.pi/4, np.pi/2, 3*np.pi/4, np.pi])
G = np.array([5, 3, 0, -3, 5])

# %%
fig, ax = plt.subplots(figsize=(7,3))

ax.plot(T,G, 'bo:')
ax.stem(T,G)

ax.set_ylabel(r'Amplitude [$G$]')
ax.set_xlabel(r'Time [$T$]')

ax.xaxis.set_major_formatter(FuncFormatter(
   lambda val,pos: '{:.2f}$\pi$'.format(val/np.pi) if val !=0 else '0'
))
ax.xaxis.set_major_locator(MultipleLocator(base=np.pi/4))
plt.grid()

# %% [markdown]
# ## Bonus Graphs for Part 1

# %%
def plot_complexmat(mat, title):

    vect1_re = mat[:,0].real
    vect2_re = mat[:,1].real
    
    vect1_im = mat[:,0].imag
    vect2_im = mat[:,1].imag
    
    fig, axes = plt.subplots(1,2, figsize=(10,4))
    
    
    fig.suptitle(f'Vector plot for {title}')
    axes[0].set_title('Real Plot')
    axes[0].quiver(0,0, vect1_re[0]+1e-2, vect1_re[1]+1e-2, label='vector 1', color='red',
                   scale=1, scale_units='xy', angles='xy')
    axes[0].quiver(0,0, vect2_re[0]+1e-2, vect2_re[1]+1e-2, label='vector 2', color='blue',
                   scale=1, scale_units='xy', angles='xy')
    
    axes[1].set_title('Imaginary Plot')
    axes[1].quiver(0,0, vect1_im[0]+1e-2, vect1_im[1]+1e-2, label='vector 1', color='red',
                   scale=1, scale_units='xy', angles='xy')
    axes[1].quiver(0,0, vect2_im[0]+1e-2, vect2_im[1]+1e-2, label='vector 2', color='blue',
                   scale=1, scale_units='xy', angles='xy')
    
    for i in range(len(axes)):
        axes[i].set_xlim(-2,2)
        axes[i].set_ylim(-2,2)
        axes[i].legend()
        axes[i].grid()

# %%
## Part 1.1 HY
plot_complexmat(manual_1_1, r'$H\cdot Y$')

# %%
## Part 1.2 YH
plot_complexmat(manual_1_2, r'$Y\cdot H$')

# %%
## Part 1.3 HH
plot_complexmat(manual_1_3, r'$H\cdot H$')

# %%
## Part 1.4 YHO
plot_complexmat(manual_1_4, r'$Y \cdot H \cdot O$')

# %%
## Part 1.5 HYHO
plot_complexmat(manual_1_5, r'$H \cdot Y \cdot H \cdot O$')
